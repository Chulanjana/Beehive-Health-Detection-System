# %%
from sklearn.ensemble import IsolationForest
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Select only MFCC features
mfcc_features = df_combined[[f"mfcc_{i}" for i in range(1, 14)]]

# Remove any missing values
mfcc_features = mfcc_features.dropna()

# Fit Isolation Forest
iso_forest = IsolationForest(n_estimators=100, contamination=0.05, random_state=42)
df_combined['anomaly'] = iso_forest.fit_predict(mfcc_features)

# Anomalies are marked as -1, normal as 1
df_combined['anomaly_label'] = df_combined['anomaly'].map({1: "Normal", -1: "Anomaly"})

# Count anomalies
print(df_combined['anomaly_label'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       3 import matplotlib.pyplot as plt
#       5 # Select only MFCC features
# ----> 6 mfcc_features = df_combined[[f"mfcc_{i}" for i in range(1, 14)]]
#       8 # Remove any missing values
#       9 mfcc_features = mfcc_features.dropna()
#
# NameError: name 'df_combined' is not defined
